# %% [markdown]
# # Importation de libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import zscore
from sklearn.cluster import KMeans #importation de Kmeans
from sklearn.model_selection import train_test_split 
from collections import Counter
from sklearn import tree
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_validate 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %%
dataF = pd.read_csv("Data6.txt",sep="\t")

# %% [markdown]
# # Attribute selection

# %%
dataF.isna().sum()
# Out:
# Time                                                                                                                     3
# Time Code                                                                                                                5
# Country Name                                                                                                             5
# Country Code                                                                                                             5
# Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]                                                                   16
# Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]                                                               22
# GDP (current US$) [NY.GDP.MKTP.CD]                                                                                      18
# Individuals using the Internet (% of population) [IT.NET.USER.ZS]                                                       20
# Maternal mortality ratio (modeled estimate, per 100,000 live births) [SH.STA.MMRT]                                      38
# Refugee population by country or territory of origin [SM.POP.REFG.OR]                                                   32
# Unemployment, female (% of female labor force) (modeled ILO estimate) [SL.UEM.TOTL.FE.ZS]                               36
# Unemployment, male (% of male labor force) (modeled ILO estimate) [SL.UEM.TOTL.MA.ZS]                                   36
# Unemployment, total (% of total labor force) (modeled ILO estimate) [SL.UEM.TOTL.ZS]                                    36
# CO2 emissions (kt) [EN.ATM.CO2E.KT]                                                                                     20
# Forest area (% of land area) [AG.LND.FRST.ZS]                                                                           14
# Methane emissions (kt of CO2 equivalent) [EN.ATM.METH.KT.CE]                                                            17
# Nitrous oxide emissions (% change from 1990) [EN.ATM.NOXE.ZG]                                                           18
# Number of deaths ages 5-14 years [SH.DTH.0514]                                                                          30
# Number of infant deaths [SH.DTH.IMRT]                                                                                   30
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) [EN.ATM.PM25.MC.ZS]        29
# Population growth (annual %) [SP.POP.GROW]                                                                               6
# Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]                                                        29
# Population ages 0-14, female [SP.POP.0014.FE.IN]                                                                        29
# Population ages 0-14, female (% of female population) [SP.POP.0014.FE.ZS]                                               29
# Population ages 0-14, male (% of male population) [SP.POP.0014.MA.ZS]                                                   29
# Population ages 0-14, total [SP.POP.0014.TO]                                                                            29
# Population ages 15-64, female (% of female population) [SP.POP.1564.FE.ZS]                                              29
# Population ages 15-64, male (% of male population) [SP.POP.1564.MA.ZS]                                                  29
# Population ages 15-64 (% of total population) [SP.POP.1564.TO.ZS]                                                       29
# Population, total [SP.POP.TOTL]                                                                                          6
# Suicide mortality rate, male (per 100,000 male population) [SH.STA.SUIC.MA.P5]                                          40
# Suicide mortality rate, female (per 100,000 female population) [SH.STA.SUIC.FE.P5]                                      40
# Suicide mortality rate (per 100,000 population) [SH.STA.SUIC.P5]                                                        40
# Population density (people per sq. km of land area) [EN.POP.DNST]                                                        8
# Renewable energy consumption (% of total final energy consumption) [EG.FEC.RNEW.ZS]                                     12
# Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]                                                     58
# Employers, female (% of female employment) (modeled ILO estimate) [SL.EMP.MPYR.FE.ZS]                                   36
# Employers, male (% of male employment) (modeled ILO estimate) [SL.EMP.MPYR.MA.ZS]                                       36
# Employers, total (% of total employment) (modeled ILO estimate) [SL.EMP.MPYR.ZS]                                        36
# International migrant stock, total [SM.POP.TOTL]                                                                         8
# Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.MA.ZS]         36
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.ZS]          36
# Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.FE.ZS]     36
# Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.MA.ZS]                 36
# Labor force participation rate for ages 15-24, female (%) (national estimate) [SL.TLF.ACTI.1524.FE.NE.ZS]              137
# Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.ZS]                   36
# dtype: int64

# %%
dataF = dataF.drop(['Time', 'Time Code', 'Country Code','Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]', 'Labor force participation rate for ages 15-24, female (%) (national estimate) [SL.TLF.ACTI.1524.FE.NE.ZS]','Population ages 0-14, total [SP.POP.0014.TO]'], axis = 1)

dataF.rename(columns = {'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]': 'Birth rate',
                     'Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]': 'Fertility rate',
                     'GDP (current US$) [NY.GDP.MKTP.CD]': 'GDP',
                     'Individuals using the Internet (% of population) [IT.NET.USER.ZS]': 'Individuals using the internet',
                     'Maternal mortality ratio (modeled estimate, per 100,000 live births) [SH.STA.MMRT]': 'Maternal mortality ratio',
                     'Refugee population by country or territory of origin [SM.POP.REFG.OR]': 'Refugee population',
                     'Unemployment, female (% of female labor force) (modeled ILO estimate) [SL.UEM.TOTL.FE.ZS]': 'Unemployed female',
                     'Unemployment, male (% of male labor force) (modeled ILO estimate) [SL.UEM.TOTL.MA.ZS]': 'Unemployed male',
                     'Unemployment, total (% of total labor force) (modeled ILO estimate) [SL.UEM.TOTL.ZS]': 'Unemployed total',
                      'CO2 emissions (kt) [EN.ATM.CO2E.KT]': 'CO2 emissions',
                      'Forest area (% of land area) [AG.LND.FRST.ZS]': 'Forest area',
                      'Methane emissions (kt of CO2 equivalent) [EN.ATM.METH.KT.CE]': 'Methane emissions',
                      'Nitrous oxide emissions (thousand metric tons of CO2 equivalent) [EN.ATM.NOXE.KT.CE]': 'Nitrous oxide emissions',
                      'Number of deaths ages 5-14 years [SH.DTH.0514]': 'Number of death ages 5-14 years',
                      'Number of infant deaths [SH.DTH.IMRT]': 'Number of infant death',
                      'PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) [EN.ATM.PM25.MC.ZS]': 'PM2.5 air pollution',
                      'Population growth (annual %) [SP.POP.GROW]': 'Population growth',
                      'Population density (people per sq. km of land area) [EN.POP.DNST]': 'Population density',
                      'Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]': 'Population ages 0-14',
                      'Population ages 0-14, female (% of female population) [SP.POP.0014.FE.ZS]': 'Population ages 0-14, female',
                      'Population ages 0-14, male (% of male population) [SP.POP.0014.MA.ZS]': 'Population ages 0-14, male',
                      'Suicide mortality rate, male (per 100,000 male population) [SH.STA.SUIC.MA.P5]': 'Suicide mortality rate, male',
                      'Suicide mortality rate, female (per 100,000 female population) [SH.STA.SUIC.FE.P5]': 'Suicide mortality rate, female',
                      'Suicide mortality rate (per 100,000 population) [SH.STA.SUIC.P5]': 'Suicide mortality rate',
                      'Renewable energy consumption (% of total final energy consumption) [EG.FEC.RNEW.ZS]': 'Renewable energy',
                     'Employers, female (% of female employment) (modeled ILO estimate) [SL.EMP.MPYR.FE.ZS]': 'Employers female',
                     'Employers, male (% of male employment) (modeled ILO estimate) [SL.EMP.MPYR.MA.ZS]': 'Employers male',
                     'Employers, total (% of total employment) (modeled ILO estimate) [SL.EMP.MPYR.ZS]': 'Employers total',
                     'International migrant stock (% of population) [SM.POP.TOTL.ZS]': 'International migrant stock',
                     'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.FE.ZS]': 'Labor force participation rate (15+), female',
                     'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.MA.ZS]': 'Labor force participation rate (15+), male',
                     'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.ZS]': 'Labor force participation rate (15+), total',
                     'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.ZS]': 'Labor force particiation rate (15-64), total',
                     'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.MA.ZS]': 'Labor force participation rate (15-64), male',
                     'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.FE.ZS]': 'Labor force participation rate (15-64), female','Population ages 15-64, female (% of female population) [SP.POP.1564.FE.ZS]': 'Population ages 15-64, female',
                    'Population ages 15-64, male (% of male population) [SP.POP.1564.MA.ZS]': 'Population ages 15-64, male',
                    'Population ages 15-64 (% of total population) [SP.POP.1564.TO.ZS]': 'Population ages 15-64',
                    'Population, total [SP.POP.TOTL]': 'Population, total',
                    'International migrant stock, total [SM.POP.TOTL]': 'International migrant stock',
                    'Nitrous oxide emissions (% change from 1990) [EN.ATM.NOXE.ZG]': 'Nitrous oxide emissions',
                     }, inplace = True)

dataF = dataF.drop(['Population ages 0-14, female [SP.POP.0014.FE.IN]'], axis = 1)

# %% [markdown]
# # Object selection

# %%
dataF=dataF.dropna(axis=0)
dataF = dataF.reset_index(drop=True) # to regenerate consecutive integer row names
dataF.head()
# Out:
#   Country Name  Birth rate  Fertility rate           GDP  \
# 0  Afghanistan      39.829           5.977  1.585657e+10
# 1      Albania      12.001           1.660  1.192695e+10
# 2      Algeria      24.504           2.860  1.612073e+11
# 3       Angola      45.656           6.194  8.379950e+10
# 4    Argentina      18.154           2.346  4.236274e+11
#
#    Individuals using the internet  Maternal mortality ratio  \
# 0                             4.0                     954.0
# 1                            45.0                      21.0
# 2                            12.5                     115.0
# 3                             2.8                     326.0
# 4                            45.0                      51.0
#
#    Refugee population  Unemployed female  Unemployed male  Unemployed total  \
# 0           3054709.0              2.920            1.961             2.275
# 1             14772.0             15.882           12.763            14.086
# 2              6689.0             19.090            8.106             9.960
# 3            134858.0              9.556            8.624             9.089
# 4               557.0              9.212            6.679             7.714
#
#    ...  Renewable energy  Employers female  Employers male  Employers total  \
# 0  ...         14.839806             0.115           0.672            0.490
# 1  ...         37.115330             0.453           2.361            1.569
# 2  ...          0.258072             1.509           4.089            3.697
# 3  ...         54.193837             2.474           5.844            4.168
# 4  ...          8.961446             2.900           5.589            4.508
#
#    International migrant stock  Labor force participation rate (15+), male  \
# 0                     102246.0                                   82.704002
# 1                      52784.0                                   62.984001
# 2                     244964.0                                   70.045998
# 3                      76549.0                                   80.464996
# 4                    1805957.0                                   74.322998
#
#    Labor force participation rate (15+), total  \
# 0                                    63.292000
# 1                                    54.271000
# 2                                    42.362000
# 3                                    77.802002
# 4                                    60.610001
#
#    Labor force participation rate (15+), female  \
# 0                                     42.735001
# 1                                     45.693001
# 2                                     14.379000
# 3                                     75.306999
# 4                                     47.833000
#
#    Labor force participation rate (15-64), male  \
# 0                                     71.277000
# 1                                     37.998001
# 2                                     46.698002
# 3                                     58.404999
# 4                                     49.636002
#
#    Labor force particiation rate (15-64), total
# 0                                     54.126999
# 1                                     32.469002
# 2                                     28.240999
# 3                                     57.995998
# 4                                     41.002998
#
# [5 rows x 39 columns]

# %%
corr=dataF.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col1 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col3 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col4 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col5 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col6 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col7 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col8 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col10 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col11 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col12 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col13 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col14 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col15 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col16 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col17 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col18 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col19 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col20 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col21 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col22 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col23 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col24 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col25 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col26 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col27 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col28 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col29 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col30 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col31 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col32 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col33 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col34 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col35 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col36 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow0_col37 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col0 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col3 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col4 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col5 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col6 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col7 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col9 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col10 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col11 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col12 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col13 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col14 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col15 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col16 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col17 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col18 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col19 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7a56a62e_265c_11ea_8558_38c9865439bfrow1_col21 {
#             background-color:  #

# %% [markdown]
# # Problematique ?
# Est-ce que le taux de suicide augmente avec la pollution ? pays qui attirent le plus de migrants sont ceux qui ont des conditions environnementales favorables (faible PM2.5 et grandes zones forestières) ou ceux où la participation dans le travail et plus forte? Est-ce que le niveau de vie joue - t-il un rôle important au moment de choisir un pays où immigrer (population growth, suicide mortality rate)

# %%
mycolumns=['CO2 emissions','Forest area','PM2.5 air pollution'
           ,'Nitrous oxide emissions',
          'Renewable energy','Suicide mortality rate']

# %%
dataF2=dataF[mycolumns]

# %%
corr2=dataF2.corr()
corr2.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col1 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col3 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col5 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col0 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col4 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col5 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col0 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col3 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col4 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col5 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow3_col0 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow3_col1 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow3_col2 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow3_col4 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow4_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow4_col2 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow4_col3 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow4_col5 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow5_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow5_col1 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e4af560_265e_11ea_8558_38c9865439bfrow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_9e4af560_265e_11ea_8558_38c9865439bf" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CO2 emissions</th>        <th class="col_heading level0 col1" >Forest area</th>        <th class="col_heading level0 col2" >PM2.5 air pollution</th>        <th class="col_heading level0 col3" >Nitrous oxide emissions</th>        <th class="col_heading level0 col4" >Renewable energy</th>        <th class="col_heading level0 col5" >Suicide mortality rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e4af560_265e_11ea_8558_38c9865439bflevel0_row0" class="row_heading level0 row0" >CO2 emissions</th>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col1" class="data row0 col1" >0.0019</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col2" class="data row0 col2" >-0.03</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col3" class="data row0 col3" >-0.041</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col4" class="data row0 col4" >-0.18</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow0_col5" class="data row0 col5" >0.1</td>
#             </tr>
#             <tr>
#                         <th id="T_9e4af560_265e_11ea_8558_38c9865439bflevel0_row1" class="row_heading level0 row1" >Forest area</th>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col0" class="data row1 col0" >0.0019</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col2" class="data row1 col2" >-0.13</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col3" class="data row1 col3" >-0.075</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col4" class="data row1 col4" >0.18</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow1_col5" class="data row1 col5" >0.17</td>
#             </tr>
#             <tr>
#                         <th id="T_9e4af560_265e_11ea_8558_38c9865439bflevel0_row2" class="row_heading level0 row2" >PM2.5 air pollution</th>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col0" class="data row2 col0" >-0.03</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col1" class="data row2 col1" >-0.13</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col3" class="data row2 col3" >0.19</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col4" class="data row2 col4" >0.074</td>
#                         <td id="T_9e4af560_265e_11ea_8558_38c9865439bfrow2_col5" class="data row2 col5" >-0.14</td>
#             </tr>
#             <tr>
#                         <th id="T

# %%
dataF2.head()
# Out:
#    CO2 emissions  Forest area  PM2.5 air pollution  Nitrous oxide emissions  \
# 0       8463.436     2.067825           100.000000                22.136681
# 1       4598.418    28.332116           100.000000               -27.981393
# 2     119177.500     0.805294           100.000000                47.007196
# 3      29057.308    46.907837           100.000000               -79.857727
# 4     187919.082    10.449119            99.447641                35.154320
#
#    Renewable energy  Suicide mortality rate
# 0         14.839806                     5.1
# 1         37.115330                     7.8
# 2          0.258072                     3.3
# 3         54.193837                     5.7
# 4          8.961446                     8.7

# %% [markdown]
# ## Nouvelle variable, definition des classes d'objets

# %%
n, bins, patches=plt.hist(dataF2['Suicide mortality rate'],bins=[0,6,10,15,40])

# %%
n,sum(n)
# Out:
# (array([65., 63., 54., 35.]), 217.0)

# %%
pourcentage=[]
for i in range(len(dataF2)):
    if dataF2['Suicide mortality rate'][i]<6:
        pourcentage.append('< 6%')
    elif dataF2['Suicide mortality rate'][i]>=6 and dataF2['Suicide mortality rate'][i]<10 :
        pourcentage.append('6-10%')
    elif dataF2['Suicide mortality rate'][i]>=10 and dataF2['Suicide mortality rate'][i]<15 :
        pourcentage.append('10-15%')
    elif dataF2['Suicide mortality rate'][i]>=15:
        pourcentage.append('> 15%')

# %%
dataF2['Suicide mortality rate']=pourcentage
# Out:
# /Users/catalinagonzalez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dataF2.head()
# Out:
#    CO2 emissions  Forest area  PM2.5 air pollution  Nitrous oxide emissions  \
# 0       8463.436     2.067825           100.000000                22.136681
# 1       4598.418    28.332116           100.000000               -27.981393
# 2     119177.500     0.805294           100.000000                47.007196
# 3      29057.308    46.907837           100.000000               -79.857727
# 4     187919.082    10.449119            99.447641                35.154320
#
#    Renewable energy Suicide mortality rate
# 0         14.839806                   < 6%
# 1         37.115330                  6-10%
# 2          0.258072                   < 6%
# 3         54.193837                   < 6%
# 4          8.961446                  6-10%

# %% [markdown]
# ## Definition de une nouvelle data frame

# %%
mycolumns=['CO2 emissions','Forest area','PM2.5 air pollution'
           ,'Nitrous oxide emissions',
          'Renewable energy','Suicide mortality rate']
dataF3=dataF2[mycolumns]

# %%
dataF3.head()
# Out:
#    CO2 emissions  Forest area  PM2.5 air pollution  Nitrous oxide emissions  \
# 0       8463.436     2.067825           100.000000                22.136681
# 1       4598.418    28.332116           100.000000               -27.981393
# 2     119177.500     0.805294           100.000000                47.007196
# 3      29057.308    46.907837           100.000000               -79.857727
# 4     187919.082    10.449119            99.447641                35.154320
#
#    Renewable energy Suicide mortality rate
# 0         14.839806                   < 6%
# 1         37.115330                  6-10%
# 2          0.258072                   < 6%
# 3         54.193837                   < 6%
# 4          8.961446                  6-10%

# %% [markdown]
# # Visualisation des données

# %%
dataF3.describe(include='all')
# Out:
#         CO2 emissions  Forest area  PM2.5 air pollution  \
# count    2.170000e+02   217.000000           217.000000
# unique            NaN          NaN                  NaN
# top               NaN          NaN                  NaN
# freq              NaN          NaN                  NaN
# mean     1.355759e+06    31.077404            94.123985
# std      4.112499e+06    21.361405            19.387918
# min      9.900900e+01     0.000000             0.735150
# 25%      4.679092e+03    12.708940            99.508177
# 50%      4.411401e+04    30.869964           100.000000
# 75%      3.530331e+05    44.008726           100.000000
# max      3.347238e+07    98.403846           100.000000
#
#         Nitrous oxide emissions  Renewable energy Suicide mortality rate
# count                217.000000        217.000000                    217
# unique                      NaN               NaN                      4
# top                         NaN               NaN                   < 6%
# freq                        NaN               NaN                     65
# mean                  18.175613         33.335944                    NaN
# std                   62.335509         28.982086                    NaN
# min                  -79.857727          0.000000                    NaN
# 25%                  -24.396363          9.359817                    NaN
# 50%                   14.421255         24.544339                    NaN
# 75%                   35.154320         54.193837                    NaN
# max                  356.966020         96.827822                    NaN

# %% [markdown]
# ### Normlaisation des données
#
# Pour déterminer des groupes de vins qui se ressemblent, on commence par normaliser les données car nos
# variables ont des unités très différentes. Cette étape permet de donner le même poids à chaque variable (pour
# que les variables ayant des valeurs plus grandes n’aient pas une influence disproportionnée).

# %%
cols =list(dataF3.columns)
cols.remove('Suicide mortality rate')

# %%
dataF3[cols]=dataF3[cols].apply(zscore,axis=0)

# %%
dataF3.describe()
# Out:
#        CO2 emissions   Forest area  PM2.5 air pollution  \
# count   2.170000e+02  2.170000e+02         2.170000e+02
# mean    8.185976e-17  6.031562e-17        -2.228440e-16
# std     1.002312e+00  1.002312e+00         1.002312e+00
# min    -3.304061e-01 -1.458203e+00        -4.827995e+00
# 25%    -3.292898e-01 -8.618785e-01         2.783507e-01
# 50%    -3.196786e-01 -9.733425e-03         3.037769e-01
# 75%    -2.443878e-01  6.067588e-01         3.037769e-01
# max     7.827570e+00  3.159067e+00         3.037769e-01
#
#        Nitrous oxide emissions  Renewable energy
# count             2.170000e+02      2.170000e+02
# mean             -1.227896e-17      2.148819e-17
# std               1.002312e+00      1.002312e+00
# min              -1.576309e+00     -1.152885e+00
# 25%              -6.845281e-01     -8.291868e-01
# 50%              -6.036749e-02     -3.040475e-01
# 75%               2.730059e-01      7.213462e-01
# max               5.447517e+00      2.195794e+00

# %%
dataF3.head()
# Out:
#    CO2 emissions  Forest area  PM2.5 air pollution  Nitrous oxide emissions  \
# 0      -0.328367    -1.361177             0.303777                 0.063691
# 1      -0.329309    -0.128813             0.303777                -0.742173
# 2      -0.301384    -1.420417             0.303777                 0.463592
# 3      -0.323348     0.742790             0.303777                -1.576309
# 4      -0.284630    -0.967913             0.275221                 0.273006
#
#    Renewable energy Suicide mortality rate
# 0         -0.639668                   < 6%
# 1          0.130706                  6-10%
# 2         -1.143960                   < 6%
# 3          0.721346                   < 6%
# 4         -0.842964                  6-10%

# %%
#sns.scatterplot(data=dataF3, hue='Suicide mortality rate')
sns.pairplot(data=dataF3, vars=dataF3.columns[0:4], hue='Suicide mortality rate')

# %% [markdown]
# ## Identification des outliers (?)

# %%
dataF3.boxplot()

# %% [markdown]
# # Recherche de clusters
# On réalise un clustering hiérarchique en méthode single avec distance euclidienne sur notre jeu
# de données. Nous cherchons ici à déterminer des clusters de type contour. Cette représentation nous permet
# aussi de prendre une décision quant à nos outliers.

# %% [markdown]
# ## Kmeans
# Nous cherchons des clusters sphériques grâce à la méthode des k-means.
# Afin de déterminer le nombre de groupes que l’on va créer, on fait varier le nombre de groupes dans notre
# k-means puis on calcule la SSE totale de notre clustering. Le nombre de groupes que l’on retient est
# celui qui donne une SSE suffisamment faible avec un nombre de groupes suffisamment petit.

# %%
classes = dataF3['Suicide mortality rate']
objects = dataF3.drop(['Suicide mortality rate'],axis=1)

# %%
# Get SSE when varying the number of clusters
sse_list = []
k_list = range(2,11)
for i in k_list:
    km_i_clusters=KMeans(n_clusters=i)
    km_i_clusters.fit(objects)
    sse_list = sse_list + [km_i_clusters.inertia_]
print(sse_list)
# Out:
# [878.5784755839813, 682.1771766949103, 515.9754511663803, 409.34561327955976, 330.70860644304787, 289.2506088639191, 261.5606458738925, 244.8918044885224, 223.30400163374946]

# %%
fig = plt.figure(figsize=(7, 4))
plt.plot(k_list,sse_list,'bo--')
plt.grid()
plt.xlabel("nb of clusters",fontsize=14)
plt.ylabel("SSE",fontsize=14)
# Out:
# Text(0, 0.5, 'SSE')

# %% [markdown]
# SSE: la somme des écarts au carré de la différence (distance) entre un point de jeu de données et son centroide (cluster).
# On ne regarde pas la SSE mais le gain en SSE (de 2 à 3 il y a un grand gain).
#
# Le nombre optimal de clusters pour notre jeu de données semble être 5

# %%
km=KMeans(n_clusters=5)
km.fit(objects) # compute the clusters --> lancer le kmeans
centroids=km.cluster_centers_

# %%
sns.scatterplot(data=dataF3, x="Forest area", y="Nitrous oxide emissions", hue='Suicide mortality rate')
# plot the centroids
sns.regplot(x=centroids[:,dataF3.columns.get_loc("Forest area")], y=centroids[:,dataF3.columns.get_loc("Nitrous oxide emissions")],
            scatter=True, fit_reg=False, marker='x', scatter_kws={"s": 100}, color="r")

# %% [markdown]
# ### Étude de la stabilité de la convergence de K-means

# %% [markdown]
# ## Hierarchical clustering (complete/single)

# %% [markdown]
# ### Deandrograms for hierarchical clustering

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# # CLASSIFICATION

# %%
X = dataF3.drop(['Suicide mortality rate'],axis=1)
Y=dataF3['Suicide mortality rate']

# %%
#On randomize la BD pour pouvoir avoir un jeu d'entrainement et un jeu test
#Random_state: on fixe la graine du générateur pseudo aléatoire
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=10)

# %%
#On vérifier la distribution 
Counter(Y_test)
# Out:
# Counter({'10-15%': 22, '< 6%': 18, '> 15%': 8, '6-10%': 24})

# %%
dt= tree.DecisionTreeClassifier() #constructeur de decision tree

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
Y_predict=dt.predict(X_test)

# %% [markdown]
# ## Confusion matrix

# %%
#lignes vrai classes des objets
#colonnes classes des predits 
pd.crosstab(Y_test,Y_predict)
# Out:
# col_0                   10-15%  6-10%  < 6%  > 15%
# Suicide mortality rate
# 10-15%                      15      1     3      3
# 6-10%                        2      8     8      6
# < 6%                         4      2    10      2
# > 15%                        2      1     2      3

# %% [markdown]
# ## Metrics

# %%
accuracy_score(Y_test,Y_predict)
# Out:
# 0.5

# %%
precision_score(Y_test,Y_predict,average="weighted"), precision_score(Y_test,Y_predict,average="macro")
# Out:
# (0.5540027605244997, 0.4919772256728778)

# %%
recall_score(Y_test,Y_predict,average="weighted"), recall_score(Y_test,Y_predict,average="macro")
# Out:
# (0.5, 0.4864267676767677)

# %%
f1_score(Y_test,Y_predict,average="weighted"), f1_score(Y_test,Y_predict,average="macro")
# Out:
# (0.5041061016670771, 0.4679108154717911)

# %%
print(classification_report(Y_test, Y_predict))
# Out:
#               precision    recall  f1-score   support
#
#       10-15%       0.65      0.68      0.67        22
#        6-10%       0.67      0.33      0.44        24
#         < 6%       0.43      0.56      0.49        18
#        > 15%       0.21      0.38      0.27         8
#
#     accuracy                           0.50        72
#    macro avg       0.49      0.49      0.47        72
# weighted avg       0.55      0.50      0.50        72
