# %% [markdown]
# # Importation de libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import zscore
from sklearn.cluster import KMeans #importation de Kmeans
from sklearn.model_selection import train_test_split 
from collections import Counter
from sklearn import tree
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_validate 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %%
dataF = pd.read_csv("Data6.txt",sep="\t")

# %% [markdown]
# # Attribute selection

# %%
dataF.isna().sum()
# Out:
# Time                                                                                                                     3
# Time Code                                                                                                                5
# Country Name                                                                                                             5
# Country Code                                                                                                             5
# Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]                                                                   16
# Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]                                                               22
# GDP (current US$) [NY.GDP.MKTP.CD]                                                                                      18
# Individuals using the Internet (% of population) [IT.NET.USER.ZS]                                                       20
# Maternal mortality ratio (modeled estimate, per 100,000 live births) [SH.STA.MMRT]                                      38
# Refugee population by country or territory of origin [SM.POP.REFG.OR]                                                   32
# Unemployment, female (% of female labor force) (modeled ILO estimate) [SL.UEM.TOTL.FE.ZS]                               36
# Unemployment, male (% of male labor force) (modeled ILO estimate) [SL.UEM.TOTL.MA.ZS]                                   36
# Unemployment, total (% of total labor force) (modeled ILO estimate) [SL.UEM.TOTL.ZS]                                    36
# CO2 emissions (kt) [EN.ATM.CO2E.KT]                                                                                     20
# Forest area (% of land area) [AG.LND.FRST.ZS]                                                                           14
# Methane emissions (kt of CO2 equivalent) [EN.ATM.METH.KT.CE]                                                            17
# Nitrous oxide emissions (% change from 1990) [EN.ATM.NOXE.ZG]                                                           18
# Number of deaths ages 5-14 years [SH.DTH.0514]                                                                          30
# Number of infant deaths [SH.DTH.IMRT]                                                                                   30
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) [EN.ATM.PM25.MC.ZS]        29
# Population growth (annual %) [SP.POP.GROW]                                                                               6
# Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]                                                        29
# Population ages 0-14, female [SP.POP.0014.FE.IN]                                                                        29
# Population ages 0-14, female (% of female population) [SP.POP.0014.FE.ZS]                                               29
# Population ages 0-14, male (% of male population) [SP.POP.0014.MA.ZS]                                                   29
# Population ages 0-14, total [SP.POP.0014.TO]                                                                            29
# Population ages 15-64, female (% of female population) [SP.POP.1564.FE.ZS]                                              29
# Population ages 15-64, male (% of male population) [SP.POP.1564.MA.ZS]                                                  29
# Population ages 15-64 (% of total population) [SP.POP.1564.TO.ZS]                                                       29
# Population, total [SP.POP.TOTL]                                                                                          6
# Suicide mortality rate, male (per 100,000 male population) [SH.STA.SUIC.MA.P5]                                          40
# Suicide mortality rate, female (per 100,000 female population) [SH.STA.SUIC.FE.P5]                                      40
# Suicide mortality rate (per 100,000 population) [SH.STA.SUIC.P5]                                                        40
# Population density (people per sq. km of land area) [EN.POP.DNST]                                                        8
# Renewable energy consumption (% of total final energy consumption) [EG.FEC.RNEW.ZS]                                     12
# Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]                                                     58
# Employers, female (% of female employment) (modeled ILO estimate) [SL.EMP.MPYR.FE.ZS]                                   36
# Employers, male (% of male employment) (modeled ILO estimate) [SL.EMP.MPYR.MA.ZS]                                       36
# Employers, total (% of total employment) (modeled ILO estimate) [SL.EMP.MPYR.ZS]                                        36
# International migrant stock, total [SM.POP.TOTL]                                                                         8
# Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.MA.ZS]         36
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.ZS]          36
# Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.FE.ZS]     36
# Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.MA.ZS]                 36
# Labor force participation rate for ages 15-24, female (%) (national estimate) [SL.TLF.ACTI.1524.FE.NE.ZS]              137
# Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.ZS]                   36
# dtype: int64

# %%
dataF = dataF.drop(['Time', 'Time Code', 'Country Code','Armed forces personnel (% of total labor force) [MS.MIL.TOTL.TF.ZS]', 'Labor force participation rate for ages 15-24, female (%) (national estimate) [SL.TLF.ACTI.1524.FE.NE.ZS]','Population ages 0-14, total [SP.POP.0014.TO]'], axis = 1)

dataF.rename(columns = {'Birth rate, crude (per 1,000 people) [SP.DYN.CBRT.IN]': 'Birth rate',
                     'Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]': 'Fertility rate',
                     'GDP (current US$) [NY.GDP.MKTP.CD]': 'GDP',
                     'Individuals using the Internet (% of population) [IT.NET.USER.ZS]': 'Individuals using the internet',
                     'Maternal mortality ratio (modeled estimate, per 100,000 live births) [SH.STA.MMRT]': 'Maternal mortality ratio',
                     'Refugee population by country or territory of origin [SM.POP.REFG.OR]': 'Refugee population',
                     'Unemployment, female (% of female labor force) (modeled ILO estimate) [SL.UEM.TOTL.FE.ZS]': 'Unemployed female',
                     'Unemployment, male (% of male labor force) (modeled ILO estimate) [SL.UEM.TOTL.MA.ZS]': 'Unemployed male',
                     'Unemployment, total (% of total labor force) (modeled ILO estimate) [SL.UEM.TOTL.ZS]': 'Unemployed total',
                      'CO2 emissions (kt) [EN.ATM.CO2E.KT]': 'CO2 emissions',
                      'Forest area (% of land area) [AG.LND.FRST.ZS]': 'Forest area',
                      'Methane emissions (kt of CO2 equivalent) [EN.ATM.METH.KT.CE]': 'Methane emissions',
                      'Nitrous oxide emissions (thousand metric tons of CO2 equivalent) [EN.ATM.NOXE.KT.CE]': 'Nitrous oxide emissions',
                      'Number of deaths ages 5-14 years [SH.DTH.0514]': 'Number of death ages 5-14 years',
                      'Number of infant deaths [SH.DTH.IMRT]': 'Number of infant death',
                      'PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) [EN.ATM.PM25.MC.ZS]': 'PM2.5 air pollution',
                      'Population growth (annual %) [SP.POP.GROW]': 'Population growth',
                      'Population density (people per sq. km of land area) [EN.POP.DNST]': 'Population density',
                      'Population ages 0-14 (% of total population) [SP.POP.0014.TO.ZS]': 'Population ages 0-14',
                      'Population ages 0-14, female (% of female population) [SP.POP.0014.FE.ZS]': 'Population ages 0-14, female',
                      'Population ages 0-14, male (% of male population) [SP.POP.0014.MA.ZS]': 'Population ages 0-14, male',
                      'Suicide mortality rate, male (per 100,000 male population) [SH.STA.SUIC.MA.P5]': 'Suicide mortality rate, male',
                      'Suicide mortality rate, female (per 100,000 female population) [SH.STA.SUIC.FE.P5]': 'Suicide mortality rate, female',
                      'Suicide mortality rate (per 100,000 population) [SH.STA.SUIC.P5]': 'Suicide mortality rate',
                      'Renewable energy consumption (% of total final energy consumption) [EG.FEC.RNEW.ZS]': 'Renewable energy',
                     'Employers, female (% of female employment) (modeled ILO estimate) [SL.EMP.MPYR.FE.ZS]': 'Employers female',
                     'Employers, male (% of male employment) (modeled ILO estimate) [SL.EMP.MPYR.MA.ZS]': 'Employers male',
                     'Employers, total (% of total employment) (modeled ILO estimate) [SL.EMP.MPYR.ZS]': 'Employers total',
                     'International migrant stock (% of population) [SM.POP.TOTL.ZS]': 'International migrant stock',
                     'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.FE.ZS]': 'Labor force participation rate (15+), female',
                     'Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.MA.ZS]': 'Labor force participation rate (15+), male',
                     'Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.ZS]': 'Labor force participation rate (15+), total',
                     'Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.ZS]': 'Labor force particiation rate (15-64), total',
                     'Labor force participation rate for ages 15-24, male (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.MA.ZS]': 'Labor force participation rate (15-64), male',
                     'Labor force participation rate for ages 15-24, female (%) (modeled ILO estimate) [SL.TLF.ACTI.1524.FE.ZS]': 'Labor force participation rate (15-64), female','Population ages 15-64, female (% of female population) [SP.POP.1564.FE.ZS]': 'Population ages 15-64, female',
                    'Population ages 15-64, male (% of male population) [SP.POP.1564.MA.ZS]': 'Population ages 15-64, male',
                    'Population ages 15-64 (% of total population) [SP.POP.1564.TO.ZS]': 'Population ages 15-64',
                    'Population, total [SP.POP.TOTL]': 'Population, total',
                    'International migrant stock, total [SM.POP.TOTL]': 'International migrant stock',
                    'Nitrous oxide emissions (% change from 1990) [EN.ATM.NOXE.ZG]': 'Nitrous oxide emissions',
                     }, inplace = True)

dataF = dataF.drop(['Population ages 0-14, female [SP.POP.0014.FE.IN]'], axis = 1)

# %% [markdown]
# # Object selection

# %%
dataF=dataF.dropna(axis=0)
dataF = dataF.reset_index(drop=True) # to regenerate consecutive integer row names
dataF.head()
# Out:
#   Country Name  Birth rate  Fertility rate           GDP  \
# 0  Afghanistan      39.829           5.977  1.585657e+10
# 1      Albania      12.001           1.660  1.192695e+10
# 2      Algeria      24.504           2.860  1.612073e+11
# 3       Angola      45.656           6.194  8.379950e+10
# 4    Argentina      18.154           2.346  4.236274e+11
#
#    Individuals using the internet  Maternal mortality ratio  \
# 0                             4.0                     954.0
# 1                            45.0                      21.0
# 2                            12.5                     115.0
# 3                             2.8                     326.0
# 4                            45.0                      51.0
#
#    Refugee population  Unemployed female  Unemployed male  Unemployed total  \
# 0           3054709.0              2.920            1.961             2.275
# 1             14772.0             15.882           12.763            14.086
# 2              6689.0             19.090            8.106             9.960
# 3            134858.0              9.556            8.624             9.089
# 4               557.0              9.212            6.679             7.714
#
#    ...  Renewable energy  Employers female  Employers male  Employers total  \
# 0  ...         14.839806             0.115           0.672            0.490
# 1  ...         37.115330             0.453           2.361            1.569
# 2  ...          0.258072             1.509           4.089            3.697
# 3  ...         54.193837             2.474           5.844            4.168
# 4  ...          8.961446             2.900           5.589            4.508
#
#    International migrant stock  Labor force participation rate (15+), male  \
# 0                     102246.0                                   82.704002
# 1                      52784.0                                   62.984001
# 2                     244964.0                                   70.045998
# 3                      76549.0                                   80.464996
# 4                    1805957.0                                   74.322998
#
#    Labor force participation rate (15+), total  \
# 0                                    63.292000
# 1                                    54.271000
# 2                                    42.362000
# 3                                    77.802002
# 4                                    60.610001
#
#    Labor force participation rate (15+), female  \
# 0                                     42.735001
# 1                                     45.693001
# 2                                     14.379000
# 3                                     75.306999
# 4                                     47.833000
#
#    Labor force participation rate (15-64), male  \
# 0                                     71.277000
# 1                                     37.998001
# 2                                     46.698002
# 3                                     58.404999
# 4                                     49.636002
#
#    Labor force particiation rate (15-64), total
# 0                                     54.126999
# 1                                     32.469002
# 2                                     28.240999
# 3                                     57.995998
# 4                                     41.002998
#
# [5 rows x 39 columns]

# %%
corr=dataF.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col1 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col3 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col4 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col5 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col6 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col7 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col8 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col10 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col11 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col12 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col13 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col14 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col15 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col16 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col17 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col18 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col19 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col20 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col21 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col22 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col23 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col24 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col25 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col26 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col27 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col28 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col29 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col30 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col31 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col32 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col33 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col34 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col35 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col36 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow0_col37 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col0 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col3 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col4 {
#             background-color:  #d55042;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col5 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col6 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col7 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col9 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col10 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col11 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col12 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col13 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col14 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col15 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col16 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col17 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col18 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col19 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_93ef324e_2658_11ea_bbe4_38c9865439bfrow1_col21 {
#             background-color:  #

# %% [markdown]
# # Problematique ?
# Est-ce que les pays qui attirent le plus de migrants sont ceux qui ont des conditions environnementales favorables (faible PM2.5 et grandes zones forestières) ou ceux où la participation dans le travail et plus forte? Est-ce que le niveau de vie joue - t-il un rôle important au moment de choisir un pays où immigrer (population growth, suicide mortality rate)

# %%
mycolumns=['International migrant stock','Population, total','Forest area','PM2.5 air pollution'
           ,'Population growth','Suicide mortality rate',
          'Labor force particiation rate (15-64), total']

# %%
dataF2=dataF[mycolumns]

# %%
corr2=dataF2.corr()
corr2.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col1 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col2 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col4 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col5 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col6 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow1_col0 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow1_col2 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow1_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow1_col4 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow1_col5 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow1_col6 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow2_col0 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow2_col1 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow2_col3 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow2_col4 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow2_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow2_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow3_col1 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow3_col2 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow3_col4 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow3_col5 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow4_col3 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow4_col6 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow5_col0 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow5_col1 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow5_col2 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow5_col3 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow5_col6 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow6_col0 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow6_col1 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow6_col2 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow6_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow6_col4 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow6_col5 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_940c70a2_2658_11ea_bbe4_38c9865439bfrow6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_940c70a2_2658_11ea_bbe4_38c9865439bf" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >International migrant stock</th>        <th class="col_heading level0 col1" >Population, total</th>        <th class="col_heading level0 col2" >Forest area</th>        <th class="col_heading level0 col3" >PM2.5 air pollution</th>        <th class="col_heading level0 col4" >Population growth</th>        <th class="col_heading level0 col5" >Suicide mortality rate</th>        <th class="col_heading level0 col6" >Labor force particiation rate (15-64), total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_940c70a2_2658_11ea_bbe4_38c9865439bflevel0_row0" class="row_heading level0 row0" >International migrant stock</th>
#                         <td id="T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col1" class="data row0 col1" >0.72</td>
#                         <td id="T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col2" class="data row0 col2" >-0.016</td>
#                         <td id="T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col3" class="data row0 col3" >-0.096</td>
#                         <td id="T_940c70a2_2658_11ea_bbe4_38c9865439bfrow0_col4" class="data row0 col4" >-0.095</td>
#                         <td id="T_940c70a2_2658_11ea_bbe4_38c98

# %%
dataF2.head()
# Out:
#    International migrant stock  Population, total  Forest area  \
# 0                     102246.0         29185507.0     2.067825
# 1                      52784.0          2913021.0    28.332116
# 2                     244964.0         35977455.0     0.805294
# 3                      76549.0         23356246.0    46.907837
# 4                    1805957.0         40788453.0    10.449119
#
#    PM2.5 air pollution  Population growth  Suicide mortality rate  \
# 0           100.000000           2.746576                     5.1
# 1           100.000000          -0.496462                     7.8
# 2           100.000000           1.805019                     3.3
# 3           100.000000           3.671462                     5.7
# 4            99.447641           0.752213                     8.7
#
#    Labor force particiation rate (15-64), total
# 0                                     54.126999
# 1                                     32.469002
# 2                                     28.240999
# 3                                     57.995998
# 4                                     41.002998

# %% [markdown]
# ## Nouvelle variable, definition des classes d'objets

# %%
dataF2['International migrant rate']=dataF2['International migrant stock']/dataF2['Population, total']*100
# Out:
# /Users/catalinagonzalez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dataF2.head()
# Out:
#    International migrant stock  Population, total  Forest area  \
# 0                     102246.0         29185507.0     2.067825
# 1                      52784.0          2913021.0    28.332116
# 2                     244964.0         35977455.0     0.805294
# 3                      76549.0         23356246.0    46.907837
# 4                    1805957.0         40788453.0    10.449119
#
#    PM2.5 air pollution  Population growth  Suicide mortality rate  \
# 0           100.000000           2.746576                     5.1
# 1           100.000000          -0.496462                     7.8
# 2           100.000000           1.805019                     3.3
# 3           100.000000           3.671462                     5.7
# 4            99.447641           0.752213                     8.7
#
#    Labor force particiation rate (15-64), total  International migrant rate
# 0                                     54.126999                    0.350331
# 1                                     32.469002                    1.812002
# 2                                     28.240999                    0.680882
# 3                                     57.995998                    0.327745
# 4                                     41.002998                    4.427618

# %%
n, bins, patches=plt.hist(dataF2['International migrant rate'],bins=[0,1,2,5,12,100])

# %%
n,sum(n)
# Out:
# (array([47., 44., 52., 38., 36.]), 217.0)

# %%
pourcentage=[]
for i in range(len(dataF2)):
    if dataF2['International migrant rate'][i]<1:
        pourcentage.append('< 1%')
    elif dataF2['International migrant rate'][i]>=1 and dataF2['International migrant rate'][i]<2 :
        pourcentage.append('1-2%')
    elif dataF2['International migrant rate'][i]>=2 and dataF2['International migrant rate'][i]<5 :
        pourcentage.append('2-5%')
    elif dataF2['International migrant rate'][i]>=5 and dataF2['International migrant rate'][i]<12 :
        pourcentage.append('5-12%')
    elif dataF2['International migrant rate'][i]>=12:
        pourcentage.append('> 12%')

# %%
dataF2['International migrant rate classes']=pourcentage
# Out:
# /Users/catalinagonzalez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dataF2.head()
# Out:
#    International migrant stock  Population, total  Forest area  \
# 0                     102246.0         29185507.0     2.067825
# 1                      52784.0          2913021.0    28.332116
# 2                     244964.0         35977455.0     0.805294
# 3                      76549.0         23356246.0    46.907837
# 4                    1805957.0         40788453.0    10.449119
#
#    PM2.5 air pollution  Population growth  Suicide mortality rate  \
# 0           100.000000           2.746576                     5.1
# 1           100.000000          -0.496462                     7.8
# 2           100.000000           1.805019                     3.3
# 3           100.000000           3.671462                     5.7
# 4            99.447641           0.752213                     8.7
#
#    Labor force particiation rate (15-64), total  International migrant rate  \
# 0                                     54.126999                    0.350331
# 1                                     32.469002                    1.812002
# 2                                     28.240999                    0.680882
# 3                                     57.995998                    0.327745
# 4                                     41.002998                    4.427618
#
#   International migrant rate classes
# 0                               < 1%
# 1                               1-2%
# 2                               < 1%
# 3                               < 1%
# 4                               2-5%

# %% [markdown]
# ## Definition de une nouvelle data frame

# %%
mycolumns=['Forest area','PM2.5 air pollution'
           ,'Population growth','Suicide mortality rate',
          'Labor force particiation rate (15-64), total','International migrant rate classes']
dataF3=dataF2[mycolumns]

# %%
dataF3.head()
# Out:
#    Forest area  PM2.5 air pollution  Population growth  \
# 0     2.067825           100.000000           2.746576
# 1    28.332116           100.000000          -0.496462
# 2     0.805294           100.000000           1.805019
# 3    46.907837           100.000000           3.671462
# 4    10.449119            99.447641           0.752213
#
#    Suicide mortality rate  Labor force particiation rate (15-64), total  \
# 0                     5.1                                     54.126999
# 1                     7.8                                     32.469002
# 2                     3.3                                     28.240999
# 3                     5.7                                     57.995998
# 4                     8.7                                     41.002998
#
#   International migrant rate classes
# 0                               < 1%
# 1                               1-2%
# 2                               < 1%
# 3                               < 1%
# 4                               2-5%

# %% [markdown]
# # Visualisation des données

# %%
dataF3.describe(include='all')
# Out:
#         Forest area  PM2.5 air pollution  Population growth  \
# count    217.000000           217.000000         217.000000
# unique          NaN                  NaN                NaN
# top             NaN                  NaN                NaN
# freq            NaN                  NaN                NaN
# mean      31.077404            94.123985           1.519207
# std       21.361405            19.387918           1.473117
# min        0.000000             0.735150          -2.096943
# 25%       12.708940            99.508177           0.521665
# 50%       30.869964           100.000000           1.312914
# 75%       44.008726           100.000000           2.412542
# max       98.403846           100.000000          11.482901
#
#         Suicide mortality rate  Labor force particiation rate (15-64), total  \
# count               217.000000                                    217.000000
# unique                     NaN                                           NaN
# top                        NaN                                           NaN
# freq                       NaN                                           NaN
# mean                 10.077536                                     45.355154
# std                   6.786317                                     12.804799
# min                   1.900000                                     14.167000
# 25%                   5.400000                                     36.473000
# 50%                   8.100000                                     44.289001
# 75%                  12.700000                                     53.704544
# max                  40.000000                                     79.844002
#
#        International migrant rate classes
# count                                 217
# unique                                  5
# top                                  2-5%
# freq                                   52
# mean                                  NaN
# std                                   NaN
# min                                   NaN
# 25%                                   NaN
# 50%                                   NaN
# 75%                                   NaN
# max                                   NaN

# %% [markdown]
# ### Normlaisation des données
#
# Pour déterminer des groupes de vins qui se ressemblent, on commence par normaliser les données car nos
# variables ont des unités très différentes. Cette étape permet de donner le même poids à chaque variable (pour
# que les variables ayant des valeurs plus grandes n’aient pas une influence disproportionnée).

# %%
cols =list(dataF3.columns)
cols.remove('International migrant rate classes')

# %%
dataF3[cols]=dataF3[cols].apply(zscore,axis=0)
# Out:
# /Users/catalinagonzalez/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
dataF3.describe()
# Out:
#         Forest area  PM2.5 air pollution  Population growth  \
# count  2.170000e+02         2.170000e+02       2.170000e+02
# mean   6.031562e-17        -2.228440e-16       7.879002e-17
# std    1.002312e+00         1.002312e+00       1.002312e+00
# min   -1.458203e+00        -4.827995e+00      -2.460438e+00
# 25%   -8.618785e-01         2.783507e-01      -6.787306e-01
# 50%   -9.733425e-03         3.037769e-01      -1.403627e-01
# 75%    6.067588e-01         3.037769e-01       6.078270e-01
# max    3.159067e+00         3.037769e-01       6.779321e+00
#
#        Suicide mortality rate  Labor force particiation rate (15-64), total
# count            2.170000e+02                                  2.170000e+02
# mean            -3.031369e-17                                 -6.197040e-17
# std              1.002312e+00                                  1.002312e+00
# min             -1.207790e+00                                 -2.441293e+00
# 25%             -6.908535e-01                                 -6.952621e-01
# 50%             -2.920742e-01                                 -8.345447e-02
# 75%              3.873276e-01                                  6.535592e-01
# max              4.419429e+00                                  2.699659e+00

# %%
dataF3.head()
# Out:
#    Forest area  PM2.5 air pollution  Population growth  \
# 0    -1.361177             0.303777           0.835105
# 1    -0.128813             0.303777          -1.371466
# 2    -1.420417             0.303777           0.194467
# 3     0.742790             0.303777           1.464400
# 4    -0.967913             0.275221          -0.521865
#
#    Suicide mortality rate  Labor force particiation rate (15-64), total  \
# 0               -0.735162                                      0.686627
# 1               -0.336383                                     -1.008680
# 2               -1.001015                                     -1.339633
# 3               -0.646545                                      0.989478
# 4               -0.203457                                     -0.340671
#
#   International migrant rate classes
# 0                               < 1%
# 1                               1-2%
# 2                               < 1%
# 3                               < 1%
# 4                               2-5%

# %%
#sns.scatterplot(data=dataF3, hue="International migrant rate classes")
sns.pairplot(data=dataF3, vars=dataF3.columns[0:5], hue="International migrant rate classes")

# %% [markdown]
# ## Identification des outliers (?)

# %%
dataF3.boxplot()

# %% [markdown]
# # Recherche de clusters
# On réalise un clustering hiérarchique en méthode single avec distance euclidienne sur notre jeu
# de données. Nous cherchons ici à déterminer des clusters de type contour. Cette représentation nous permet
# aussi de prendre une décision quant à nos outliers.

# %% [markdown]
# ## Kmeans
# Nous cherchons des clusters sphériques grâce à la méthode des k-means.
# Afin de déterminer le nombre de groupes que l’on va créer, on fait varier le nombre de groupes dans notre
# k-means puis on calcule la SSE totale de notre clustering. Le nombre de groupes que l’on retient est
# celui qui donne une SSE suffisamment faible avec un nombre de groupes suffisamment petit.

# %%
classes = dataF3['International migrant rate classes']
objects = dataF3.drop(['International migrant rate classes'],axis=1)

# %%
# Get SSE when varying the number of clusters
sse_list = []
k_list = range(2,11)
for i in k_list:
    km_i_clusters=KMeans(n_clusters=i)
    km_i_clusters.fit(objects)
    sse_list = sse_list + [km_i_clusters.inertia_]
print(sse_list)
# Out:
# [859.0352072807982, 681.7533798310849, 549.5489419283842, 473.3283043474447, 411.26039748530366, 359.7160686463272, 332.97923973375623, 309.5322604557714, 292.38366634592614]

# %%
fig = plt.figure(figsize=(7, 4))
plt.plot(k_list,sse_list,'bo--')
plt.grid()
plt.xlabel("nb of clusters",fontsize=14)
plt.ylabel("SSE",fontsize=14)
# Out:
# Text(0, 0.5, 'SSE')

# %% [markdown]
# SSE: la somme des écarts au carré de la différence (distance) entre un point de jeu de données et son centroide (cluster).
# On ne regarde pas la SSE mais le gain en SSE (de 2 à 3 il y a un grand gain).
#
# Le nombre optimal de clusters pour notre jeu de données semble être 4

# %%
km=KMeans(n_clusters=4)
km.fit(objects) # compute the clusters --> lancer le kmeans
centroids=km.cluster_centers_

# %%
sns.scatterplot(data=dataF3, x="Forest area", y="Labor force particiation rate (15-64), total", hue='International migrant rate classes')
# plot the centroids
sns.regplot(x=centroids[:,dataF3.columns.get_loc("Forest area")], y=centroids[:,dataF3.columns.get_loc("Labor force particiation rate (15-64), total")],
            scatter=True, fit_reg=False, marker='x', scatter_kws={"s": 100}, color="r")

# %% [markdown]
# ### Étude de la stabilité de la convergence de K-means

# %% [markdown]
# ## Hierarchical clustering (complete/single)

# %% [markdown]
# ### Deandrograms for hierarchical clustering

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# # CLASSIFICATION

# %%
X = dataF3.drop(['International migrant rate classes'],axis=1)
Y=dataF3['International migrant rate classes']

# %%
#On randomize la BD pour pouvoir avoir un jeu d'entrainement et un jeu test
#Random_state: on fixe la graine du générateur pseudo aléatoire
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=10)

# %%
#On vérifier la distribution 
Counter(Y_test)
# Out:
# Counter({'5-12%': 12, '< 1%': 12, '2-5%': 19, '1-2%': 17, '> 12%': 12})

# %%
dt= tree.DecisionTreeClassifier() #constructeur de decision tree

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
Y_predict=dt.predict(X_test)

# %% [markdown]
# ## Confusion matrix

# %%
#lignes vrai classes des objets
#colonnes classes des predits 
pd.crosstab(Y_test,Y_predict)
# Out:
# col_0                               1-2%  2-5%  5-12%  < 1%  > 12%
# International migrant rate classes
# 1-2%                                   5     4      3     3      2
# 2-5%                                   4     8      3     3      1
# 5-12%                                  2     3      3     3      1
# < 1%                                   1     3      3     5      0
# > 12%                                  1     2      2     1      6

# %% [markdown]
# ## Metrics

# %%
accuracy_score(Y_test,Y_predict)
# Out:
# 0.375

# %%
precision_score(Y_test,Y_predict,average="weighted"), precision_score(Y_test,Y_predict,average="macro")
# Out:
# (0.38763736263736265, 0.3864468864468865)

# %%
recall_score(Y_test,Y_predict,average="weighted"), recall_score(Y_test,Y_predict,average="macro")
# Out:
# (0.375, 0.3763673890608875)

# %%
f1_score(Y_test,Y_predict,average="weighted"), f1_score(Y_test,Y_predict,average="macro")
# Out:
# (0.3780648363981698, 0.37803677803677804)

# %%
print(classification_report(Y_test, Y_predict))
# Out:
#               precision    recall  f1-score   support
#
#         1-2%       0.38      0.29      0.33        17
#         2-5%       0.40      0.42      0.41        19
#        5-12%       0.21      0.25      0.23        12
#         < 1%       0.33      0.42      0.37        12
#        > 12%       0.60      0.50      0.55        12
#
#     accuracy                           0.38        72
#    macro avg       0.39      0.38      0.38        72
# weighted avg       0.39      0.38      0.38        72

# %%
dataF=dataF.drop(['Unemployed female', 'Unemployed male','Population ages 0-14, female',
                  'Population ages 0-14, male','Population ages 15-64, female',
                  'Population ages 15-64, male','Suicide mortality rate, male',
                  'Suicide mortality rate, female','Employers female','Employers male',
                  'Labor force rate, male','Labor force rate, female',
                  'Labor force participation rate, male','Fertility rate',
                  'Maternal mortality ratio','Population ages 0-14','Population ages 15-64','Methane emissions',
                  'International migrant stock','Population, total''Number of death ages 5-14 years',
                  'Number of infant death','Labor force rate, total','Renewable energy','CO2 emissions',
                  'Birth rate','Methane emissions','International migrant stock','Population, total'],axis=1)
